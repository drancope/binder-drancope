# %%
print("hola")
# Out:
# hola

# %%
print("caracola")
# Out:
# caracola

# %% [markdown]
# Pulsar Shift+Enter para ejecutar secuencialmente
# En el menú de celdas se puede cambiar el tipo de celda, desde "código" a "markdown".
# Aquí se podría editar la tipografía, tamaños, etc.
